# %% [markdown]
# # Marvel Heroes
# ## Adriel Zagala

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#imports needed to visualize and tranform the dataset

# %%
df = pd.read_csv('charcters_stats.csv')
#saving dataset to dataframe

# %% [markdown]
# ### Cleaning Data

# %%
df
# prints the dataframe
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability
# 0            3-D Man      good            50        31     43          32  \
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %% [markdown]
# ---

# %% [markdown]
# - Show the first record from the csv

# %%
df.head(1)
#only print the first record from the csv
# Out:
#       Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0  3-D Man      good            50        31     43          32     25  \
#
#    Combat  Total
# 0      52    233

# %% [markdown]
# - Show the number of rows and columns

# %%
print("Number of columns: ",len(df.columns))
print("Number of rows: ",len(df))

#prints the number of columns and rows
# Out:
# Number of columns:  9
# Number of rows:  611

# %% [markdown]
# - Find the amount of characters who fall under each alignment, you can use value_counts()

# %%
df['Alignment'].value_counts()

#prints the count of the alignments that are good and bad
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# Name: count, dtype: int64

# %% [markdown]
# - Find only the good alignment characters

# %%
good_chars = df[df['Alignment']== 'good'].reset_index(drop = True)
good_chars

#prints the good character dataframe with a good alignemnt value and its index resetted
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability
# 0            3-D Man      good            50        31     43          32  \
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 427            X-Man      good            88        53     53          95
# 428     Yellowjacket      good            88        10     12          28
# 429  Yellowjacket II      good            50        10     35          28
# 430             Ymir      good            50       100     27         100
# 431          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %% [markdown]
# - Show only the first five records from the previous bullet point

# %%
good_chars[:5]
#only prints the top 5 rows
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0      3-D Man      good            50        31     43          32     25  \
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      64    320

# %% [markdown]
# - Select the top five heroes with the highest speed who have a good alignment

# %%
good_fast = good_chars.sort_values('Speed', ascending=False).reset_index(drop = True)
good_fast[:5]

# prints the top 5 good speed cahracters and its index reset
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0       Flash III      good            63        10    100          60     83  \
# 1  Jack of Hearts      good            63        55    100          30     70
# 2         Impulse      good            50        10    100          60     63
# 3        Stardust      good            88        85    100         110    100
# 4     Quicksilver      good            63        28    100          60     57
#
#    Combat  Total
# 0      32    348
# 1      30    348
# 2      60    343
# 3      85    568
# 4      56    364

# %% [markdown]
# - Select five heroes with maximum power who have a good alignment

# %%
good_powerful = good_chars.sort_values('Power', ascending=False).reset_index(drop = True)
good_powerful[:5]

# prints the top 5 good powerful cahracters and its index reset
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0        Zatanna      good            75        10     23          28    100  \
# 1           Thor      good            69       100     92         100    100
# 2          Spawn      good            75        60     50          90    100
# 3  Beta Ray Bill      good            63        80     35          95    100
# 4       Beyonder      good            88       100     23         100    100
#
#    Combat  Total
# 0      56    292
# 1      85    546
# 2      95    470
# 3      84    457
# 4      56    467

# %% [markdown]
# - Find out how many superheroes there are with power of 100 with good alignment

# %%
good_power_100 = good_chars[good_chars['Power'] == 100]
print("Number of Characters with the power of 100: ",len(good_power_100))

# prints the good alignment characters with only the power level of 100 and its count
# Out:
# Number of Characters with the power of 100:  33

# %% [markdown]
# - Shape them what you got in point 10

# %%
good_power_100.shape

# prints the shape of the dataframe
# Out:
# (33, 9)

# %% [markdown]
# - Show all records from point 10

# %%
good_power_100

#shows the 33 characters
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability
# 54       Beta Ray Bill      good            63        80     35          95  \
# 55            Beyonder      good            88       100     23         100
# 63          Black Bolt      good            75        67    100          84
# 94               Cable      good            88        48     23          56
# 136            Deadman      good            50        10     33         100
# 140        Doctor Fate      good            81        16     25          80
# 141     Doctor Strange      good           100        10     12          84
# 144       Dr Manhattan      good            88        32     42          95
# 158          Firestorm      good            50        53     58          56
# 176               Goku      good            56       100     75          90
# 187         Hal Jordan      good            63        90     53          64
# ...

# %% [markdown]
# - Retrieve the first five records with max power and has good alignment

# %%
good_power_100[:5]
#prints the top 5 100 power characters
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability
# 54   Beta Ray Bill      good            63        80     35          95  \
# 55        Beyonder      good            88       100     23         100
# 63      Black Bolt      good            75        67    100          84
# 94           Cable      good            88        48     23          56
# 136        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 54     100      84    457
# 55     100      56    467
# 63     100      56    482
# 94     100      80    395
# 136    100      42    335

# %% [markdown]
# - Draw a bar plot of all superheroes who are having good alignment and a max power of the top five heroes only , take the same object of point 13, show name and total in plot with green bars

# %%
ax = good_power_100[:5].plot(kind='bar',figsize=(15,7))
plt.title('Top 5 100 Power Heroes with good alignment')
ax.set_xticklabels(good_power_100[:5].Name)
ax.set_xlabel("Character")
ax.set_ylabel("Value")
plt.show()

# creates a graph that seperates the top 5 characters with a good alignment
# a bar plot is created with thte titles set as top 5 100 power heroes

# %% [markdown]
# - Extract villains who having a bad alignment

# %%
bad_chars = df[df['Alignment']== 'bad'].reset_index(drop = True)

#creates a Dataframe that has only bad alignment characters with the index resetted

# %% [markdown]
# - Show first five records of point 15

# %%
bad_chars[:5]

#shows the 5 characters that have a bad alignment with no sort
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0  Abomination       bad            63        80     53          90     55  \
# 1      Abraxas       bad            88       100     83          99    100
# 2   Air-Walker       bad            50        85    100          85    100
# 3        Amazo       bad            75       100    100         100    100
# 4         Ammo       bad             1         1      1           1      0
#
#    Combat  Total
# 0      95    436
# 1      56    526
# 2      40    460
# 3     100    575
# 4       1      5

# %% [markdown]
# - Show top five fastest super villains in terms of super speed

# %%
bad_fast = bad_chars.sort_values('Speed', ascending=False).reset_index(drop = True)
bad_fast[:5]

# only dangerous character are presented since it shows the top 5 fastest bad alignment characters
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0            Zoom       bad            50        10    100          28     72  \
# 1      Air-Walker       bad            50        85    100          85    100
# 2           Amazo       bad            75       100    100         100    100
# 3  Superboy-Prime       bad            94       100    100         100    100
# 4     General Zod       bad            94       100     96         100     94
#
#    Combat  Total
# 0      28    288
# 1      40    460
# 2     100    575
# 3      85    579
# 4      95    579

# %% [markdown]
# - Top five super villains in terms of intelligence

# %%
bad_smart = bad_chars.sort_values('Intelligence', ascending=False).reset_index(drop = True)
bad_smart[:5]

# only dangerous character are presented since it shows the top 5 most intelligent bad alignment characters
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability
# 0  Mister Mxyzptlk       bad           113        10     12          14  \
# 1       Lex Luthor       bad           100        10     12          14
# 2           Leader       bad           100        10     12          14
# 3         Brainiac       bad           100        28     63          90
# 4      Doctor Doom       bad           100        32     20         100
#
#    Power  Combat  Total
# 0    100      28    277
# 1     10      28    174
# 2     58      42    236
# 3     60      75    416
# 4     93      84    429

# %% [markdown]
# - Show who is most dangerous super villain after calculating their total
# (top 5 only)

# %%
dangerous = bad_chars.sort_values('Total', ascending=False).reset_index(drop = True)
dangerous[:5]

# only dangerous character are presented since it shows the top 5 strongest bad alignment characters
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0  Superboy-Prime       bad            94       100    100         100    100  \
# 1     General Zod       bad            94       100     96         100     94
# 2           Amazo       bad            75       100    100         100    100
# 3        Dormammu       bad            88        95     83         100    100
# 4        Doomsday       bad            88        80     67         120    100
#
#    Combat  Total
# 0      85    579
# 1      95    579
# 2     100    575
# 3      80    546
# 4      90    545

# %% [markdown]
# ---

# %% [markdown]
# - Draw a histogram for speed of super heroes having fig size 10.5,
# provide speed in histogram for only good alignment superheroes, title
# should be "distribution of speed", xlabel should be "speed"

# %%
speed_good = good_chars.sort_values('Speed', ascending=False).reset_index(drop = True)
ax = sns.histplot(data = speed_good, x =speed_good.Speed)
ax.set_xlabel("Speed")
ax.set_ylabel("Count")
sns.set(rc={"figure.figsize":(10.5, 5)})
plt.title('Distribution of Speed')
plt.show()

# i create the histogram by selecting only data from the good characters dataframe and that the speed 
# stats are used for the x rage and the count of the combat stats are the y range

# %% [markdown]
# - Draw a histogram for combat of super villains having fig size 10.5,
# provide combat in histogram for only bad alignment superheroes, title
# should be "distribution of combat", xlabel should be "combat"

# %%
combat_bad = bad_chars.sort_values('Combat', ascending=False).reset_index(drop = True)
ax = sns.histplot(data = combat_bad, x =combat_bad.Combat)
ax.set_xlabel("Combat")
ax.set_ylabel("Count")
sns.set(rc={"figure.figsize":(10.5, 5)})
plt.title('Distribution of Combat')
plt.show() 

# i create the histogram by selecting only data from the bad characters dataframe and that the combat 
# stats are used for the x rage and the count of the combat stats are the y range

# %% [markdown]
# - Explain how you retrieve data with the help of comments in almost
# each section

# %% [markdown]
# I was able to retrieve data with the help of comments and past projects

# %% [markdown]
# - Bonus: You can go beyond the scope and extract different information
# on different characters and their properties. As well as draw some more
# plots and histograms.

# %%
neutral_chars = df[df['Alignment'] == 'neutral'].reset_index(drop = "true")
neutral_chars

#just wanted to see the characters with a neutral alignment
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power
# 0        Bizarro   neutral            75        95    100         100     95  \
# 1       Deadpool   neutral            50        15     30         100    100
# 2    Deathstroke   neutral            75        30     35         100     36
# 3       Galactus   neutral           100       100     83         100    100
# 4     Juggernaut   neutral            44       100     42         100     74
# 5        Man-Bat   neutral            38        18     50          70     33
# 6          Raven   neutral            50        10     29          70     62
# 7       Red Hood   neutral            75        12     23          28     24
# 8        Sandman   neutral            50        75     47          97     62
# 9   The Comedian   neutral            63        14     17          10     12
# 10          Toad   neutral            50        34     58          56     49
#
#     Combat  Total
# 0       85    550
# ...

# %%
ax = sns.histplot(data = neutral_chars, x = neutral_chars.Combat)
ax.set_xlabel("Combat")
ax.set_ylabel("Count")
sns.set(rc={"figure.figsize":(10.5, 5)})
plt.title('Distribution of Combat')
plt.show() 

# histogram of the number of neutral characters with their combat value as the number of counts as the y

# %%
dura_neutral = neutral_chars.sort_values('Durability', ascending=False).reset_index(drop = True)
ax = dura_neutral[:5].plot(kind='bar',figsize=(15,7))
plt.title('Top 5 100 Power Heroes with good alignment')
ax.set_xticklabels(dura_neutral[:5].Name)
ax.set_xlabel("Character")
ax.set_ylabel("Value")
plt.show()

# top 5 characters with a durability of a 100 and their specific stats
